# %% [markdown]
# # Create SVM model
# The accuracy of 100% will definitely cause overfitting but this is just a demonstration of how to create SVM classifier, model improvement will not be done here.

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
import pandas as pd
import numpy as np

from common_functions import plot_model_with_boundaries

data = np.asarray(pd.read_csv('data/svm_data.csv', header=None))
X = data[:,0:2]
y = data[:,2]

model = SVC(kernel='rbf', gamma=27)
model.fit(X,y)
y_pred = model.predict(X)

accuracy = accuracy_score(y_pred, y)
plot_model_with_boundaries(model, X, y, title="SVM with accuracy " + str(accuracy))
